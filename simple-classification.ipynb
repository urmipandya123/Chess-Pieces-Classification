# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

from tensorflow.python.client import device_lib
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image

# %%
def datagen_generator():
    datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.25,
        zoom_range=0.25,
        horizontal_flip=True,
        height_shift_range=0.5,
        validation_split=0.2
    )
    
    train = datagen.flow_from_directory(
        '/kaggle/input/chess-pieces-detection-images-dataset',
        target_size=(128, 128),
        class_mode='categorical',
        color_mode='grayscale',
        batch_size=32,
        shuffle=True,
        subset='training'
    )
    
    validation = datagen.flow_from_directory(
        '/kaggle/input/chess-pieces-detection-images-dataset',
        target_size=(128, 128),
        class_mode='categorical',
        color_mode='grayscale',
        batch_size=32,
        shuffle=True,
        subset='validation'
    )
    
    return train, validation

train, val = datagen_generator()
# Out:
# Found 523 images belonging to 5 classes.
# Found 128 images belonging to 5 classes.

# %%
def checkpoint_dir():
    checkpoint_dir = 'checkpoints/'
    
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)
        
    return checkpoint_dir

def checkpoint_path():
    
    return os.path.join(checkpoint_dir(), 'model_checkpoint')

def checkpoint_saver():
    checkpoint = tf.compat.v1.train.Saver()
    checkpoint_dir_ = checkpoint_dir()
    checkpoint_path_ = checkpoint_path()
    
    return checkpoint

# %%
def chess_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(128, 128, 1)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(512, kernel_size=(3, 3), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(1024, kernel_size=(3, 3), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(2048, kernel_size=(3, 5), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=2048, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units=5, activation='softmax')
    ])
    
    checkpoint_path_ = checkpoint_path()
    
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_path_,
        save_weights_only=False,
        monitor='loss',
        mode='min',
        save_best_only=True
    )
    
    callbacks = [
        EarlyStopping(patience=10),
        model_checkpoint_callback
    ]
    
    return model, callbacks

model, callbacks = chess_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      320
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  batch_normalization_4 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 1024)        4719616
#
#  batch_normalization_5 (Batc  (None, 4, 4, 1024)       4096
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 1024)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 2, 2, 1024)        0
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 2048)        31459328
#
#  batch_normalization_6 (Batc  (None, 2, 2, 2048)       8192
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 1, 1, 2048)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 1, 1, 2048)        0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 2048)              4196352
#
#  dropout_7 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 5)                 10245
#
# =================================================================
# Total params: 41,969,797
# Trainable params: 41,961,669
# Non-trainable params: 8,128
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(
    train,
    steps_per_epoch=train.samples//32,
    validation_data=val,
    validation_steps=val.samples//32,
    epochs=124,
    #callbacks=callbacks
)
# Out:
# Epoch 1/124
# 2023-04-25 11:15:54.324855: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 16/16 [==============================] - 20s 274ms/step - loss: 8.1189 - accuracy: 0.2207 - val_loss: 2.6601 - val_accuracy: 0.1797
# Epoch 2/124
# 16/16 [==============================] - 3s 209ms/step - loss: 2.8929 - accuracy: 0.2342 - val_loss: 4.2676 - val_accuracy: 0.2188
# Epoch 3/124
# 16/16 [==============================] - 3s 151ms/step - loss: 2.4228 - accuracy: 0.1976 - val_loss: 1.9865 - val_accuracy: 0.1797
# Epoch 4/124
# 16/16 [==============================] - 3s 156ms/step - loss: 1.9198 - accuracy: 0.2464 - val_loss: 2.4249 - val_accuracy: 0.2656
# Epoch 5/124
# 16/16 [==============================] - 3s 156ms/step - loss: 1.8140 - accuracy: 0.2261 - val_loss: 2.5363 - val_accuracy: 0.2656
# Epoch 6/124
# 16/16 [==============================] - 3s 156ms/step - loss: 1.6838 - accuracy: 0.2587 - val_loss: 1.7134 - val_accuracy: 0.1797
# Epoch 7/124
# 16/16 [==============================] - 3s 155ms/step - loss: 1.6546 - accuracy: 0.2648 - val_loss: 1.8206 - val_accuracy: 0.2656
# Epoch 8/124
# 16/16 [==============================] - 3s 165ms/step - loss: 1.6425 - accuracy: 0.2363 - val_loss: 1.5917 - val_accuracy: 0.2656
# Epoch 9/124
# 16/16 [==============================] - 3s 156ms/step - loss: 1.5922 - accuracy: 0.2627 - val_loss: 1.6754 - val_accuracy: 0.2656
# Epoch 10/124
# 16/16 [==============================] - 3s 160ms/step - loss: 1.5907 - accuracy: 0.2505 - val_loss: 1.7478 - val_accuracy: 0.2656
# Epoch 11/124
# 16/16 [==============================] - 3s 176ms/step - loss: 1.5735 - accuracy: 0.2831 - val_loss: 1.6834 - val_accuracy: 0.2656
# Epoch 12/124
# 16/16 [==============================] - 3s 154ms/step - loss: 1.5990 - accuracy: 0.2851 - val_loss: 1.6309 - val_accuracy: 0.2656
# Epoch 13/124
# 16/16 [==============================] - 3s 163ms/step - loss: 1.5724 - accuracy: 0.2831 - val_loss: 1.6529 - val_accuracy: 0.2656
# Epoch 113/124
# 16/16 [==============================] - 3s 162ms/step - loss: 0.7166 - accuracy: 0.7128 - val_loss: 0.9882 - val_accuracy: 0.5781
# Epoch 114/124
# 16/16 [==============================] - 3s 164ms/step - loss: 0.7403 - accuracy: 0.7149 - val_loss: 1.3146 - val_accuracy: 0.4688
# Epoch 115/124
# 16/16 [==============================] - 3s 163ms/step - loss: 0.7635 - accuracy: 0.6925 - val_loss: 1.1518 - val_accuracy: 0.5312
# Epoch 116/124
# 16/16 [==============================] - 3s 159ms/step - loss: 0.7385 - accuracy: 0.6945 - val_loss: 1.0595 - val_accuracy: 0.6094
# Epoch 117/124
# 16/16 [==============================] - 3s 155ms/step - loss: 0.7346 - accuracy: 0.7169 - val_loss: 0.8639 - val_accuracy: 0.6953
# Epoch 118/124
# 16/16 [==============================] - 3s 163ms/step - loss: 0.6691 - accuracy: 0.7475 - val_loss: 0.8344 - val_accuracy: 0.6719
# Epoch 119/124
# 16/16 [==============================] - 3s 155ms/step - loss: 0.6183 - accuracy: 0.7536 - val_loss: 0.7048 - val_accuracy: 0.7031
# Epoch 120/124
# 16/16 [==============================] - 3s 164ms/step - loss: 0.6470 - accuracy: 0.7637 - val_loss: 0.7800 - val_accuracy: 0.7344
# Epoch 121/124
# 16/16 [==============================] - 3s 161ms/step - loss: 0.5854 - accuracy: 0.7821 - val_loss: 1.2606 - val_accuracy: 0.4375
# Epoch 122/124
# 16/16 [==============================] - 3s 161ms/step - loss: 0.6262 - accuracy: 0.7597 - val_loss: 0.7559 - val_accuracy: 0.7188
# Epoch 123/124
# 16/16 [==============================] - 3s 155ms/step - loss: 0.6126 - accuracy: 0.7556 - val_loss: 1.1061 - val_accuracy: 0.5547
# Epoch 124/124
# 16/16 [==============================] - 3s 184ms/step - loss: 0.6552 - accuracy: 0.7475 - val_loss: 0.9688 - val_accuracy: 0.6797

# %%
img = image.load_img('/kaggle/input/chess-pieces-detection-images-dataset/Rook-resize/00000001_resized.jpg', target_size=(128, 128))

plt.imshow(img)
plt.show()

def rgb2gray(imgs, axs):
    rgb_weights = [0.2989, 0.5870, 0.1140]
    
    return np.expand_dims(np.dot(imgs, rgb_weights), axis=axs)

img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = rgb2gray(img, 3)

img_pred = model.predict(img)
print('Prediction labels: ', img_pred, '\n')

img_pred_value = np.where(img_pred == np.amax(img_pred))

if img_pred_value[1] == 0:
    print('Rook')
elif img_pred_value[1] == 1:
    print('Pawn')
elif img_pred_value[1] == 2:
    print('Knight')
elif img_pred_value[1] == 3:
    print('Queen')
else:
    print('Bishop')
# Out:
# 1/1 [==============================] - 1s 504ms/step
# Prediction labels:  [[0.0000000e+00 0.0000000e+00 1.0070589e-23 0.0000000e+00 1.0000000e+00]]
#
# Bishop

# %%
metrics_df = pd.DataFrame(history.history)

# %%
metrics_df[['loss', 'val_loss']].plot()
metrics_df[['accuracy', 'val_accuracy']].plot
plt.show()

# %%
metrics_df[['accuracy', 'val_accuracy']].plot()
plt.show()
